# %%
# version metrics https://github.com/pytorch/vision#installation

pip install jupyter notebook torch==2.2 torchvision==0.17
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: notebook in /usr/local/lib/python3.8/site-packages (6.1.1)
# Collecting torch
#   Downloading torch-2.2.2-cp38-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Collecting torchvision
#   Downloading torchvision-0.17.2-cp38-cp38-macosx_10_13_x86_64.whl.metadata (6.6 kB)
# Collecting jupyter-console (from jupyter)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.8/site-packages (from jupyter) (5.6.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.8/site-packages (from jupyter) (5.3.4)
# Collecting ipywidgets (from jupyter)
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: jupyterlab in /usr/local/lib/python3.8/site-packages (from jupyter) (2.2.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/site-packages (from notebook) (2.11.2)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.8/site-packages (from notebook) (6.0.4)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/site-packages (from notebook) (19.0.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.8/site-packages (from notebook) (20.1.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.8/site-packages (from notebook) (0.2.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.8/site-packages (from notebook) (4.3.3)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.8/site-packages (from notebook) (4.6.3)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/lib/python3.8/site-packages (from notebook) (6.1.6)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/site-packages (from notebook) (5.0.7)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/site-packages (from notebook) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.8/site-packages (from notebook) (0.8.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/site-packages (from notebook) (0.8.0)
# Collecting filelock (from torch)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /Users/gurpreetsingh/Library/Python/3.8/lib/python/site-packages (from torchvision) (1.18.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/site-packages (from torchvision) (7.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook) (2.8.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.8/site-packages (from terminado>=0.8.3->notebook) (0.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/site-packages (from traitlets>=4.2.1->notebook) (1.15.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/site-packages (from traitlets>=4.2.1->notebook) (4.4.2)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.8/site-packages (from argon2-cffi->notebook) (1.14.1)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.8/site-packages (from ipykernel->jupyter) (7.17.0)
# Requirement already satisfied: appnope in /usr/local/lib/python3.8/site-packages (from ipykernel->jupyter) (0.1.0)
# Collecting comm>=0.1.3 (from ipywidgets->jupyter)
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->jupyter)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->jupyter)
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/site-packages (from jinja2->notebook) (1.1.1)
# Collecting ipykernel (from jupyter)
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jupyter-client>=5.3.4 (from notebook)
#   Using cached jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-core>=4.6.1 (from notebook)
#   Using cached jupyter_core-5.8.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting prompt-toolkit>=3.0.30 (from jupyter-console->jupyter)
#   Using cached prompt_toolkit-3.0.51-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/site-packages (from jupyter-console->jupyter) (2.6.1)
# Collecting traitlets>=4.2.1 (from notebook)
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting debugpy>=1.6.5 (from ipykernel->jupyter)
#   Downloading debugpy-1.8.15-cp38-cp38-macosx_14_0_x86_64.whl.metadata (1.1 kB)
# Collecting ipython>=6.1.0 (from ipywidgets->jupyter)
#   Downloading ipython-8.12.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel->jupyter)
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting nest-asyncio (from ipykernel->jupyter)
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/site-packages (from ipykernel->jupyter) (20.4)
# Collecting psutil (from ipykernel->jupyter)
#   Using cached psutil-7.0.0-cp36-abi3-macosx_10_9_x86_64.whl.metadata (22 kB)
# Collecting pyzmq>=17 (from notebook)
#   Downloading pyzmq-27.0.0-cp38-cp38-macosx_10_15_universal2.whl.metadata (6.0 kB)
# Collecting tornado>=5.0 (from notebook)
#   Downloading tornado-6.4.2-cp38-abi3-macosx_10_9_x86_64.whl.metadata (2.5 kB)
# Collecting importlib-metadata>=4.8.3 (from jupyter-client>=5.3.4->notebook)
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting python-dateutil>=2.8.2 (from jupyter-client>=5.3.4->notebook)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting platformdirs>=2.5 (from jupyter-core>=4.6.1->notebook)
#   Downloading platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jupyterlab-server<2.0,>=1.1.5 in /usr/local/lib/python3.8/site-packages (from jupyterlab->jupyter) (1.2.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/site-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/site-packages (from nbconvert->jupyter) (0.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/site-packages (from nbconvert->jupyter) (3.1.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/site-packages (from nbconvert->jupyter) (1.4.2)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/site-packages (from nbconvert->jupyter) (0.4.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/site-packages (from nbconvert->jupyter) (0.6.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.8/site-packages (from nbformat->notebook) (3.2.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook) (2.20)
# Collecting zipp>=3.20 (from importlib-metadata>=4.8.3->jupyter-client>=5.3.4->notebook)
#   Downloading zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->jupyter) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->jupyter) (0.17.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->jupyter) (0.7.5)
# Collecting stack-data (from ipython>=6.1.0->ipywidgets->jupyter)
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->jupyter) (4.8.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook) (69.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab->jupyter) (2.24.0)
# Requirement already satisfied: json5 in /usr/local/lib/python3.8/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab->jupyter) (0.9.5)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.8/site-packages (from packaging->ipykernel->jupyter) (2.4.7)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /usr/local/lib/python3.8/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->jupyter) (0.7.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab->jupyter) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab->jupyter) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab->jupyter) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab->jupyter) (2020.6.20)
# Collecting executing>=1.2.0 (from stack-data->ipython>=6.1.0->ipywidgets->jupyter)
#   Using cached executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython>=6.1.0->ipywidgets->jupyter)
#   Using cached asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack-data->ipython>=6.1.0->ipywidgets->jupyter)
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading torch-2.2.2-cp38-none-macosx_10_9_x86_64.whl (150.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:03m
# Downloading torchvision-0.17.2-cp38-cp38-macosx_10_13_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.8 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 1.3 MB/s eta 0:00:00 MB/s eta 0:00:0101
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 1.3 MB/s eta 0:00:00 MB/s eta 0:00:0101
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached ipykernel-6.29.5-py3-none-any.whl (117 kB)
# Using cached jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Using cached jupyter_core-5.8.1-py3-none-any.whl (28 kB)
# Downloading pyzmq-27.0.0-cp38-cp38-macosx_10_15_universal2.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 2.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading tornado-6.4.2-cp38-abi3-macosx_10_9_x86_64.whl (434 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.3/434.3 kB 2.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading debugpy-1.8.15-cp38-cp38-macosx_14_0_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Downloading ipython-8.12.3-py3-none-any.whl (798 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.3/798.3 kB 2.1 MB/s eta 0:00:002.3 MB/s eta 0:00:01
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 2.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Using cached prompt_toolkit-3.0.51-py3-none-any.whl (387 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 1.3 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Using cached psutil-7.0.0-cp36-abi3-macosx_10_9_x86_64.whl (238 kB)
# Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-3.0.0-py3-none-any.whl (26 kB)
# Using cached executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Installing collected packages: pure-eval, mpmath, zipp, widgetsnbextension, typing-extensions, traitlets, tornado, sympy, pyzmq, python-dateutil, psutil, prompt-toolkit, platformdirs, networkx, nest-asyncio, jupyterlab_widgets, fsspec, filelock, executing, debugpy, asttokens, torch, stack-data, matplotlib-inline, jupyter-core, importlib-metadata, comm, torchvision, jupyter-client, ipython, ipywidgets, ipykernel, jupyter-console, jupyter
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 4.3.3
#     Uninstalling traitlets-4.3.3:
#       Successfully uninstalled traitlets-4.3.3
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.0.4
#     Uninstalling tornado-6.0.4:
#       Successfully uninstalled tornado-6.0.4
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 19.0.2
#     Uninstalling pyzmq-19.0.2:
#       Successfully uninstalled pyzmq-19.0.2
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.6
#     Uninstalling prompt-toolkit-3.0.6:
#       Successfully uninstalled prompt-toolkit-3.0.6
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.6.3
#     Uninstalling jupyter-core-4.6.3:
#       Successfully uninstalled jupyter-core-4.6.3
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.6
#     Uninstalling jupyter-client-6.1.6:
#       Successfully uninstalled jupyter-client-6.1.6
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.17.0
#     Uninstalling ipython-7.17.0:
#       Successfully uninstalled ipython-7.17.0
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.3.4
#     Uninstalling ipykernel-5.3.4:
#       Successfully uninstalled ipykernel-5.3.4
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed asttokens-3.0.0 comm-0.2.2 debugpy-1.8.15 executing-2.2.0 filelock-3.16.1 fsspec-2025.3.0 importlib-metadata-8.5.0 ipykernel-6.29.5 ipython-8.12.3 ipywidgets-8.1.7 jupyter-1.1.1 jupyter-client-8.6.3 jupyter-console-6.6.3 jupyter-core-5.8.1 jupyterlab_widgets-3.0.15 matplotlib-inline-0.1.7 mpmath-1.3.0 nest-asyncio-1.6.0 networkx-3.1 platformdirs-4.3.6 prompt-toolkit-3.0.51 psutil-7.0.0 pure-eval-0.2.3 python-dateutil-2.9.0.post0 pyzmq-27.0.0 stack-data-0.6.3 sympy-1.13.3 torch-2.2.2 torchvision-0.17.2 tornado-6.4.2 traitlets-5.14.3 typing-extensions-4.13.2 widgetsnbextension-4.0.14 zipp-3.20.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# Check GPU
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# PyTorch version: 2.2.2
# CUDA available: False

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Download training data from open datasets.
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)


for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using {device} device")

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cpu device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            #print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 76.5%, Avg loss: 0.664543
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 77.1%, Avg loss: 0.651793
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 77.6%, Avg loss: 0.639929
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.628900
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.618663
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.609165
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.600378
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 79.4%, Avg loss: 0.592236
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.584682
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.577662
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 80.1%, Avg loss: 0.571138
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 80.4%, Avg loss: 0.565060
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 80.6%, Avg loss: 0.559377
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 80.7%, Avg loss: 0.554042
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 80.8%, Avg loss: 0.549039
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.544368
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 81.1%, Avg loss: 0.539987
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 81.1%, Avg loss: 0.535863
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 81.3%, Avg loss: 0.531970
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 81.4%, Avg loss: 0.528297
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 81.5%, Avg loss: 0.524827
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 81.5%, Avg loss: 0.521550
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.518443
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.515494
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 81.7%, Avg loss: 0.512691
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 81.9%, Avg loss: 0.510012
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.507460
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.505019
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.502682
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.500448
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.498310
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.496256
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.494283
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.492386
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 82.6%, Avg loss: 0.490558
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.488793
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.487086
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.485437
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.483841
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.482295
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.480794
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.479334
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.477912
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.476528
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.475182
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.473866
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.472583
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.471329
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.470107
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.468912
#
# Done!

# %%
torch.save(model.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Saved PyTorch Model State to model.pth

# %%
model = NeuralNetwork().to(device)
model.load_state_dict(torch.load("model.pth", weights_only=True))
# Out:
# <All keys matched successfully>

# %%
classes = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot",
]

model.eval()
x, y = test_data[0][0], test_data[0][1]


with torch.no_grad():
    x = x.to(device)
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
    
    plt.title(actual)
    plt.axis("off")
    plt.imshow(x.squeeze(), cmap="gray")
    plt.show()
    
    plt.title(predicted)
    plt.axis("off")
    plt.imshow(pred, cmap="gray")
    plt.show()
    
    print(pred)
# Out:
# Predicted: "Ankle boot", Actual: "Ankle boot"
# tensor([[-0.0262, -0.0312,  0.0148,  0.0013,  0.0212,  0.0403, -0.0386, -0.0048,
#          -0.0629,  0.0471]])
